# %%
import PreReclaim

# %% [markdown]
# ### 6차 실험
# - 실험 사전작업: 1. browser 수동으로 띄움, 2. 페이지열기: youtube, 네이버TV 3. TV화면으로 복귀
# - 실험 순서: pre-reclaim(120MB), apps, pre-reclaim(300MB), amazon, pre-reclaim(200MB), netflix, pre-reclaim(200MB), youtube
# - 실험 결과: 개선효과 있음

# %%
files = ["../log/20170523/pr_disabled_20170523_172240.txt",
         "../log/20170523/pr_disabled_20170523_175310.txt",
         "../log/20170523/pr_disabled_20170523_182259.txt",
         "../log/20170523/pr_enabled_20170523_174227.txt",
         "../log/20170523/pr_enabled_20170523_181252.txt",
         "../log/20170523/pr_enabled_20170523_183121.txt"]
df = PreReclaim.show_result(files) 
df
# Out:
#    org.volt.apps  org.tizen.ignition  /usr/bin/wascmd -r RN1MCdNq8t.Netflix  \
# 0           12.4                14.3                                    4.8
# 1           12.8                14.3                                    4.5
# 2           12.4                15.4                                    4.9
# 3           13.1                14.1                                    3.8
# 4           12.7                13.2                                    3.8
# 5           12.6                13.2                                    3.8
#
#    /usr/bin/wascmd -r 9Ur5IzDKqV.TizenYouTube  \
# 0                                         5.5
# 1                                         5.3
# 2                                         6.1
# 3                                         3.0
# 4                                         3.1
# 5                                         3.1
#
#                                               file   sum
# 0  ../log/20170523/pr_disabled_20170523_172240.txt  37.0
# 1  ../log/20170523/pr_disabled_20170523_175310.txt  36.9
# 2  ../log/20170523/pr_disabled_20170523_182259.txt  38.8
# 3   ../log/20170523/pr_enabled_20170523_174227.txt  34.0
# 4   ../log/20170523/pr_enabled_20170523_181252.txt  32.8
# 5   ../log/20170523/pr_enabled_20170523_183121.txt  32.7

# %%
df_agg = df.groupby(df['file'].str.contains('pr_enabled')).mean()
df_agg.index = ['pr enabled', 'pr disabled']
df_agg
# Out:
#              org.volt.apps  org.tizen.ignition  \
# pr enabled       12.533333           14.666667
# pr disabled      12.800000           13.500000
#
#              /usr/bin/wascmd -r RN1MCdNq8t.Netflix  \
# pr enabled                                4.733333
# pr disabled                               3.800000
#
#              /usr/bin/wascmd -r 9Ur5IzDKqV.TizenYouTube        sum
# pr enabled                                     5.633333  37.566667
# pr disabled                                    3.066667  33.166667

# %%
PreReclaim.compare(files, 3)
